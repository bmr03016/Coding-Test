# %%
from IPython.display import Image
Image('images/문자열정수의합.png')

# %%
def solution(num_str):
    answer = 0
    for i in num_str:
        answer += int(i)
    return answer

# %% [markdown]
# num_str이 문자열이었으니 i를 int로 바꿔주는 것 주의!
