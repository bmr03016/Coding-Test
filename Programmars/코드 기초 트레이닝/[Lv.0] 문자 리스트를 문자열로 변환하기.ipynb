# %%
from IPython.display import Image
Image('images/문자리스트.png')

# %%
def solution(arr):
    answer = ''
    for i in arr:
        answer += i
    return answer

# %%
def solution(arr):
    return ''.join(arr)

# %% [markdown]
# 📍쪼개진 리스트를 join 함수를 통하여 합칠 수 있음!!
