# %%
from IPython.display import Image
Image('images/ad제거.png')

# %%
def solution(strArr):
    answer = []
    for i in strArr:
        if 'ad' in i:
            continue
        else:
            answer.append(i)
    return answer

# %% [markdown]
# - 위는 내가 작성한 답안
# - 아래는 내가 원하는 답안...??
# - 😅 좀 더 연습하자!!

# %%
def solution(strArr):
    return [word for word in strArr if 'ad' not in word]
