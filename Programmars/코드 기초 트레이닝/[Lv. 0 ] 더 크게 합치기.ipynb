# %%
from IPython.display import Image
Image('./images/더크게합치기.png')

# %%
def solution(a, b):
    return max(int(str(a) + str(b)), int(str(b) + str(a)))

# %% [markdown]
# - 문제에서 원하는 ⊕ 를 수행하려면 문자열로 바꾸고,
# - a ⊕ b 와 b ⊕ a 중 더 큰 값을 return 하라고 했으니 max 함수를 사용
