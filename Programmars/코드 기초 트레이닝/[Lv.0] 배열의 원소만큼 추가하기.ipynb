# %%
from IPython.display import Image
Image('./images/배열의원소만큼.png')

# %%
from IPython.display import Image
Image('./images/배열의원소만큼2.png')

# %%
def solution(arr):
    lst = []
    for i in arr:
        for _ in range(i):
            lst.append(i) 
    
    return lst

# %% [markdown]
# i번 만큼 반복하면서 lst.append 해주기
