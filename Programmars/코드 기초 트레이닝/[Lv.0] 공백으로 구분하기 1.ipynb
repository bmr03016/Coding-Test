# %%
from IPython.display import Image
Image('images/공백으로구분.png')

# %%
def solution(my_string):
    return list(my_string.split(" "))

# %%
my_string = "i lovr you"
my_string.split(" ")
# Out:
# ['i', 'lovr', 'you']

# %% [markdown]
# split 함수를 사용하면 list 형태로 저장되기 때문에 list를 감싸주지 않아도 되었다....그래서 아래의 답도 가능

# %%
def solution(my_string):
    return my_string.split(" ")
