# %%
from IPython.display import Image
Image('images/두수의나눗셈.png')

# %%
def solution(num1, num2):
    answer = num1 / num2 * 1000
    return int(answer)

# %% [markdown]
# 나는 위처럼 정수형으로 반환하게 처리했는데, 아래의 방식도 가능하다.

# %%
def solution(num1, num2):
    answer = (num1/num2)*1000
    return answer//1
