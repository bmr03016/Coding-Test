# %%
from IPython.display import Image
Image('images/문자열반복해서출력.png')

# %%
a, b = input().strip().split(' ')
b = int(b)

for i in range(b):
    print(a, end="")
# Out:
# string 5
# stringstringstringstringstring

# %% [markdown]
# 나는 위의 방식으로 생각했는데 밑의 풀이 방식도 있었다..!

# %%
a, b = input().strip().split(' ')
print(a * int(b))
# Out:
# string 5
# stringstringstringstringstring
