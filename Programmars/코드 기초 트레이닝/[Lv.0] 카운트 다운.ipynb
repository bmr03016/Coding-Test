# %%
from IPython.display import Image
Image('images/카운트다운.png')

# %%
def solution(start, end):
    answer = []
    for i in range(start, end-1, -1):
        answer.append(i)
    return answer

# %% [markdown]
# 위처럼 풀이했지만 아래와 같이 간단하게 표기 가능하다. 이에 익숙해지는게 좋을 듯!!😊

# %%
def solution(start, end):
    return [i for i in range(start,end-1,-1)]
