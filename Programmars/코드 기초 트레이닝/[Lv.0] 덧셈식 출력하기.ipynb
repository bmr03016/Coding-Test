# %%
from IPython.display import Image
Image('images/덧셈식출력.png')

# %%
a, b = map(int, input().strip().split(' '))
print(f"{a} + {b} = {a + b}")
# Out:
# 4 5
# 4 + 5 = 9

# %% [markdown]
# - f 스트링을 활용하여 출력하였다!
