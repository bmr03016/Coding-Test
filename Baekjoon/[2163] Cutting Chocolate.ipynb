# %% [markdown]
# # 초콜릿 자르기

# %%
from IPython.display import Image
Image('images/초코1.png')

# %%
from IPython.display import Image
Image('images/초코2.png')

# %%
N, M = map(int, input().split())
print(N*M-1)
# Out:
# 2 2
# 3

# %% [markdown]
# - 가로로 먼저 자르고 세로로 자르기 : N * M - 1
# - 세로로 먼저 자르고 가로로 자르기 : N * M - 1
#
# - 2 2 경우 이외에도 여러 가지 예제 생각해서 해봤는데, 가로로 먼저 자르든 세로로 먼저 자르든 쪼개기 횟수는 동일했다
