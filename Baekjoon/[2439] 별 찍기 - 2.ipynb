# %%
from IPython.display import Image
Image('images/별2.png')

# %%
N = int(input())
for i in range(1,N+1):
    print(" " *(N-i), "*"*i, sep="")
# Out:
# 5
#     *
#    **
#   ***
#  ****
# *****

# %% [markdown]
# 📍 sep=""는 프린트문 내에 여러 항을 출력하기 위해 ','를 쓰게 될 때 항 사이에 생기는 공백을 없애주는 코드이다.
