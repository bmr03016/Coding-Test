# %%
from IPython.display import Image
Image('images/문자열반복.png')

# %%
T = int(input())

for _ in range(T):
    r, s = input().split()
    p = ''
    for i in s:
        p += i * int(r) 
    print(p)
# Out:
# 2
# 3 ABC
# AAABBBCCC
# 5 /HTP
# /////HHHHHTTTTTPPPPP

# %% [markdown]
# 📍 p를 for _ in range(N) 뒤에 정의해야지, 예제 출력처럼 출력된다
