# %%
from IPython.display import Image
Image('./images/문자열.png')

# %%
T = int(input())

for _ in range(T):
    word = str(input())
    print(word[0], word[-1], sep="")
# Out:
# 3
# ACDKJFOWIEGHE
# AE
# O
# OO
# AB
# AB

# %% [markdown]
# 📍주의! word 넣는 것을 T번 반복해야하니 word 순서가 for문 뒤로 가야한다. (초반에 순서 잘못 풀이함...)
