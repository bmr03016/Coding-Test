# %%
from IPython.display import Image
Image('./images/2750.png')

# %%
N = int(input())
lst = []

for i in range(N):
    i = int(input())
    lst.append(i)
    lst.sort()

for j in lst:
    print(j)
# Out:
# 5
# 5
# 2
# 3
# 4
# 1
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 바로 풀 수 있었😊 이제 실버 문제에 집중하자...
