# %% [markdown]
# # 단어 공부

# %%
from IPython.display import Image
Image('images/word.png')

# %%
word = input().upper() # (1)
word_list = list(set(word)) # (2)

a = [] # (3)
for i in word_list: # (4)
    
if a.count(max(a)) >=2: # (5)
    print("?") 
    
else: 
    print(word_list[a.index(max(a))]) # (6)
# Out:
# Mississipi
# ?

# %% [markdown]
# - (1) 입력받는 문자열들을 모두 대문자로 저장
# - (2) 중복을 없앤 알파벳 리스트
# - (3) 알파벳를 count해줄 빈 리스트
# - (4) word_list에서 하나씩 원소를 꺼내, word에 i가 몇 번 있었는지 세서 빈 리스트 a에 저장
# - (5) 가장 큰 값의 개수가 2개 이상이면 ? 출력
# - (6) 그렇지 않다면, a에 저장된 값 중 가장 큰 값의 index를 찾고 word_list의 인덱스로 삼으면 가장 많이 나온 알파벳을 찾을 수 있음!
