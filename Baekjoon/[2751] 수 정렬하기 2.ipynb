# %% [markdown]
# # 🥈실버 5

# %%
from IPython.display import Image
Image('./images/2751.png')

# %%
N = int(input())
arr = []
for _ in range(N):
    arr.append(int(input()))

arr.sort()

for j in arr:
    print(j)
# Out:
# 5
# 5
# 4
# 3
# 2
# 1
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 처음에는 시간초과가 발생했는데 arr.sort를 for문 안에 두었어서 그랬다. 매번 sort할 필요는 없으니 for문 밖으로 빼주고 제출하니 통과!
