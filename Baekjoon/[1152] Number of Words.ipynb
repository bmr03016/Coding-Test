# %% [markdown]
# # 단어의 개수

# %%
from IPython.display import Image
Image('images/word1.png')

# %%
from IPython.display import Image
Image('images/word2.png')

# %%
words = input().split()
print(words)
# Out:
# The Curious Case of Benjamin Button
# ['The', 'Curious', 'Case', 'of', 'Benjamin', 'Button']

# %%
words = input().split()
print(len(words))
# Out:
# The Curious Case of Benjamin Button
# 6

# %% [markdown]
# **'단어는 공백 한 개로 구분'** 에 집중하였음
# -  공백을 기준으로 split
# - 리스트의 길이 = 단어의 개수
