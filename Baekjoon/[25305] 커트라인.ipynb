# %%
from IPython.display import Image
Image('./images/25305.png')

# %%
N, k = map(int, input().split())

x = list(map(int, input().split()))
x.sort(reverse=True) # 100 98 93 85 76

# 상받는 사람 k명 -> 2명
print(x[k-1]) # x[i] = 98
# Out:
# 5 2
# 100 76 85 93 98
# 98

# %% [markdown]
# - reverse=True을 해서 내림차순 정렬,
# - k-1 index인 값을 print해주면 된다(== 커트라인)
