# %% [markdown]
# # 브론즈 2

# %%
from IPython.display import Image
Image('./images/팰린드롬.png')

# %%
word = input()
if word == word[::-1]:
    print(1)
else:
    print(0)
# Out:
# level
# 1

# %% [markdown]
# - 팰린드롬이란 앞으로 읽어도, 거꾸로 읽어도 똑같은 단어
# - 문자열을 역순으로 다시 배열하려면 [::-1]를 해주면 쉽다.
